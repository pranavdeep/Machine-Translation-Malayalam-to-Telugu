# %%
! pip install openNMT-py -q
# Out:
#      |████████████████████████████████| 215kB 3.9MB/s
#      |████████████████████████████████| 61kB 6.1MB/s
#      |████████████████████████████████| 81kB 7.9MB/s
#      |████████████████████████████████| 14.3MB 262kB/s
#      |████████████████████████████████| 81kB 8.5MB/s
#      |████████████████████████████████| 102kB 10.8MB/s
#      |████████████████████████████████| 645kB 33.1MB/s
#      |████████████████████████████████| 748.8MB 23kB/s
#      |████████████████████████████████| 1.2MB 57.0MB/s
# ERROR: torchvision 0.9.1+cu101 has requirement torch==1.8.1, but you'll have torch 1.6.0 which is incompatible.

# %%
! onmt_train -config transformer.yaml
# Out:
# [2021-06-04 21:07:14,852 INFO] Missing transforms field for corpus_1 data, set to default: [].
# [2021-06-04 21:07:14,852 WARNING] Corpus corpus_1's weight should be given. We default it to 1 for you.
# [2021-06-04 21:07:14,852 INFO] Missing transforms field for valid data, set to default: [].
# [2021-06-04 21:07:14,852 INFO] Parsed 2 corpora from -data.
# [2021-06-04 21:07:14,852 INFO] Get special vocabs from Transforms: {'src': set(), 'tgt': set()}.
# [2021-06-04 21:07:14,852 INFO] Loading vocab from text file...
# [2021-06-04 21:07:14,852 INFO] Loading src vocabulary from mallu.vocab
# [2021-06-04 21:07:15,026 INFO] Loaded src vocab has 52695 tokens.
# [2021-06-04 21:07:15,050 INFO] Loading tgt vocabulary from telugu.vocab
# [2021-06-04 21:07:15,193 INFO] Loaded tgt vocab has 49204 tokens.
# [2021-06-04 21:07:15,213 INFO] Building fields with vocab in counters...
# [2021-06-04 21:07:15,298 INFO]  * tgt vocab size: 43962.
# [2021-06-04 21:07:15,384 INFO]  * src vocab size: 48087.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g6M72zSOQGz7GR9oQ06dNMOzNcZEc92YWCtWnlBoFwr4gKrPB0KBRI

# %%
! onmt_translate -model /content/drive/MyDrive/pranav/saved_model.pth_step_9000.pt -src /content/X_test.txt -output /content/drive/MyDrive/pranav/pred_Y.txt -gpu 0
# Out:
# [2021-06-05 02:31:09,989 INFO] Translating shard 0.
# [2021-06-05 02:32:14,035 INFO] PRED AVG SCORE: -0.6536, PRED PPL: 1.9225

# %%
import zipfile

# %%
zipfile.ZipFile('model_100_unopen.zip', mode='w', compression=zipfile.ZIP_DEFLATED).write("/content/saved_model.pth_step_100.pt")
